# %%
import pandas as pd

# %%
df=pd.read_csv("globalAirQuality.csv")
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %% [markdown]
# 18000 rows × 15 columns this much is the size of the data we have and we cannot just read and unstand such a big Data help us ,its not possible to read data of each rows and column manualy to Analyse the Data and To get insigh of Data lets see  How pandas dataframe DIffrent method help Us in that

# %%
df.head()
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 4  2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
# 4   66.423  38.997  6.919  45.615  1.085   97       13.632    76.499
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650
# 3       8.956
# ...

# %%
#Selecting rows
df["country"]
df["city"]

#we can pass the Multiple Columns
#we have passed the list of Columns for Multiple Colms Values
df[["country","city","pm10"]]
# Out:
#       country      city     pm10
# 0          US  New York  108.938
# 1          US  New York   63.043
# 2          US  New York   82.553
# 3          US  New York   79.951
# 4          US  New York   66.423
# ...       ...       ...      ...
# 17995      CH    Zurich   74.179
# 17996      CH    Zurich   47.988
# 17997      CH    Zurich   72.908
# 17998      CH    Zurich   95.152
# 17999      CH    Zurich   30.411
#
# [18000 rows x 3 columns]

# %%
df["city"]
df["city",0:3]
#we cannot use am Indexes here
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '('city', slice(0, 3, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 df["city"]
# ----> 2 df["city",0:3]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
# ...

# %%
#Try to access col bY index
df[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# lets see how to select the rows
# for selecting rows we have two ways
#
# - 1.by index  iloc
# - 2.by lable  loc

# %%
#By iloc

df.iloc[2]

#we can aslo use slicing

df.iloc[0:3]

#can we select particular column and rows for it

df.iloc[1,0:6]
df.iloc[3]
# Out:
# timestamp    2025-11-04 19:25:17.554219
# country                              US
# city                           New York
# latitude                         40.713
# longitude                       -74.006
# pm25                             32.083
# Name: 1, dtype: object

# %%
df.iloc[1:3,1:6]


#df.ilc[nrow,ncols]
#iloc ia used for the Indexes Value-->row
# Out:
#   country      city  latitude  longitude    pm25
# 1      US  New York    40.713    -74.006  32.083
# 2      US  New York    40.713    -74.006  42.250

# %%
#We cannot pass labels in the iloc
df.iloc[1:3,"city"]
#For such imp we can use loc
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:873, in _LocationIndexer._validate_tuple_indexer(self, key)
#     872 try:
# --> 873     self._validate_key(k, i)
#     874 except ValueError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1483, in _iLocIndexer._validate_key(self, key, axis)
#    1482 else:
# -> 1483     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 #We cannot pass labels in the iloc
# ...

# %%
#we have a loc is used for Lebel based Selection

df.loc[1]
df.loc[1:5,["city","country"]]
# Out:
#        city country
# 1  New York      US
# 2  New York      US
# 3  New York      US
# 4  New York      US
# 5  New York      US

# %%
df.loc[1:5,["city"]]
# Out:
#        city
# 1  New York
# 2  New York
# 3  New York
# 4  New York
# 5  New York

# %%
df.loc[0:5,["country","city"]]
# Out:
#   country      city
# 0      US  New York
# 1      US  New York
# 2      US  New York
# 3      US  New York
# 4      US  New York
# 5      US  New York

# %% [markdown]
# Whenever we try to get any df by iloc or loc always remember it dosent return new copy it just return the view if any changes has Happend to the view it will be reflected in the Actual Dataframe as well
#
# - Take a look of that Example

# %%
cities=df["city"]
cities[0]="Amravati"
df
# What is Single scaler Value ?
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_25044\3808045335.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cities[0]="Amravati"
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  Amravati    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US    Mumbai    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# ...

# %%
#You can see the Data has changed in the actualy DataSet
#To avoid this we will create a copy of it and where we are changing Value

# %%
#Set it back to new York
cities[0]="new York"
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_25044\2546898776.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cities[0]="new York"

# %%
cities1=df["city"].copy()

# %%
cities1
# Out:
# 0        New York
# 1        New York
# 2        New York
# 3        New York
# 4        New York
#            ...
# 17995      Zurich
# 17996      Zurich
# 17997      Zurich
# 17998      Zurich
# 17999      Zurich
# Name: city, Length: 18000, dtype: object

# %%
cities1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 cities1
#
# NameError: name 'cities1' is not defined

# %% [markdown]
# To select a single Scaler cell we use the at and iat
#
# what is Scaler Value?

# %%
df.at[1, "city"]
# Out:
# 'New York'

# %%
df.iat[1,1]
# Out:
# 'US'

# %%
df.iat[1,3]
# Out:
# 40.713

# %% [markdown]
# Filtering The Data
# Like want cities where AQI>100 of such condition basis filtering Of Data

# %% [markdown]
# Filtering the Data Depending Upon the column Like AQI >100

# %%
df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df[df["aqi"]>100]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 6      2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# 7      2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 8      2025-11-05 02:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17991  2025-11-19 09:25:17.554219      CH    Zurich    47.377      8.542
# 17993  2025-11-19 11:25:17.554219      CH    Zurich    47.377      8.542
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
#can aslo combine the Diffrent conditions together Like

df[(df["aqi"]>100) & (df["temperature"]<30)]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 8      2025-11-05 02:25:17.554219      US  New York    40.713    -74.006
# 12     2025-11-05 06:25:17.554219      US  New York    40.713    -74.006
# 13     2025-11-05 07:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17988  2025-11-19 06:25:17.554219      CH    Zurich    47.377      8.542
# 17993  2025-11-19 11:25:17.554219      CH    Zurich    47.377      8.542
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
#Query
# - We can pass Our Expressions in the String Dirrectly in .query

df.query("aqi>100")[["temperature","humidity"]]


#We can aslo chain an Operations
aqi_Data=df.query("aqi>100 & temperature <100")[["pm25","pm10"]]

aui_Data

# - we can aslo use the Variable Values in the Query by using @


Aqi_Value=100
df.query("aqi>@Aqi_Value")
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 6      2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# 7      2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 8      2025-11-05 02:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17991  2025-11-19 09:25:17.554219      CH    Zurich    47.377      8.542
# 17993  2025-11-19 11:25:17.554219      CH    Zurich    47.377      8.542
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

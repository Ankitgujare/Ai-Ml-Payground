# %% [markdown]
# ### Pandas is used for Data analysis
# Pandas is Build on Top of Numpy
# In Pandas we have two important Data Structure
# - series--> One diamensional Labels araay
# - Dataframe->2D Labeled Array...

# %%
import pandas as pd
#Adding New Comment for the Git issue

# %%
info={ 
"Names":["Aniket","Rahul","Prasanna"],
"CGPA":[9.2,9.0,7.8]
}


df=pd.DataFrame(info)
print(df)
# Out:
#       Names  CGPA
# 0    Aniket   9.2
# 1     Rahul   9.0
# 2  Prasanna   7.8

# %%
df
# Out:
#       Names  CGPA
# 0    Aniket   9.2
# 1     Rahul   9.0
# 2  Prasanna   7.8

# %% [markdown]
# You can see its automaticaly conveted Our Data into Dataframe (Table) and aslo added labels (Indexes) ,we cal aslo change Indexes if we want

# %% [markdown]
# We can aslo import the Data from the DB And convert it into DataFrame

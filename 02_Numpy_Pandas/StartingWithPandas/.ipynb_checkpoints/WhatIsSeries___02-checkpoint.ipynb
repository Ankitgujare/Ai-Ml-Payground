# %% [markdown]
# #### We have already Talked about What is Series
# Series is Nothing But the 1D Labeled Array

# %%
import pandas as pd
#Adding New Comment for the Git issue

# %%
#Lets create a series with Simple List
s1=pd.Series([22,23,24,25])
print(s1)
# Out:
# 0    22
# 1    23
# 2    24
# 3    25
# dtype: int64

# %%
#You can we for Each Element we have an Index 
#We can aslo access an elements based On the Index

print(s1[0])
print(s1[1])
print(s1[2])
print(s1[3])
# Out:
# 22
# 23
# 24
# 25

# %% [markdown]
# As series is a Labeled Array
# its Important to know the Diffrences between Index and Labels In series
# "a", "b", "c" → Index
#
# Those same values are also called labels
#
# index and labels are the same
# Unlike normal array positions, they can represent meaning...

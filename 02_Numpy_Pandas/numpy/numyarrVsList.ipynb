# %% [markdown]
# # NumpyArray Vs List
# - Numpy array is faster than List (Optimized in C)
# - Numpy store Data In contineous memory Block(Dosent List do that?)
# - Numpy uses Less Memory  (Optimized Storage)
# - Built in Mathematics functions
# - support Dirrect Vectorized Operation
#   -vectorized operations are those for which we dont need to traverse Over the collection
#    it just apply that particular Operation in the whole Collection

# %% [markdown]
# ## Numpy Array is faster than List Because (Optimized In C)

# %% [markdown]
# ## Numpy Array is faster than List Because (Optimized In C)

# %% [markdown]
# #### Here we will see why its faster by doing a simple Operations on large collection

# %%
import numpy as np
import time

# %%
size=1_000_000

#python List
py_List=list(range(size))
startTime=time.time()
#doing simple square for whole List
sq_list=[x**2 for x in py_List]
EndTime=time.time()
print(f"python list time {EndTime-startTime} seconds")


#Creating Numpy Array
np_arr=np.array(py_List)
startTime=time.time()
#vectorization not traverling Over whole Array for an Operation
sq_array=np_arr**2
EndTime=time.time()
print(f"Numpy Array time {EndTime-startTime} seconds")
# Out:
# python list time 0.6119937896728516 seconds
# Numpy Array time 0.0029637813568115234 seconds
